# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import sys
sys.path.append('/home/francesco/KU/codes/')
import bme_sas as bme

# %%
exp = np.loadtxt('exp_saxs.txt')[...,1]

# %%
calc = np.loadtxt('calc_saxs.txt', usecols = range(1,1044))
Iav = np.mean(calc,axis=0)

# %%
rew0 = bme.Reweight()
rew0.load('exp_saxs.txt','calc_saxs.txt')
t = 40
chi2_before0, chi2_after0, srel0 = rew0.optimize(theta=t)
print(int(t), chi2_before0, chi2_after0, np.exp(srel0))
# Out:
# # theta: 40
# 40 3.7030843047444706 1.2195259536393648 0.23691421956033537

# %%
#############################################################################à####

# %%
model = LinearRegression()
model.fit(Iav.reshape(-1,1),exp)
beta = model.intercept_
alpha = model.coef_

# %%
new_calc_raw = alpha*calc+beta 
new_calc = []
new_calc = open('tmp', 'w')
for i in range(0,np.shape(new_calc_raw)[0]):
    new_calc.write('frame'+str(i)+' '+' '.join(str(n) for n in new_calc_raw[i])+'\n')
new_calc.close()

# %%
rew = bme.Reweight()
rew.load('exp_saxs.txt', 'tmp')

# %%
t = 40
chi2_before, chi2_after, srel = rew.optimize(theta=t)
print(int(t), chi2_before, chi2_after, np.exp(srel))
# Out:
# # theta: 40
# 40 3.522109554870506 1.1326868910814643 0.588561976376942

# %%
calc_rew = []
for i in range(0,np.shape(new_calc_raw)[1]):
    calc_rew.append((new_calc_raw[...,i]*weights).sum())
calc_rew = np.array(calc_rew)

# %%
model1 = LinearRegression()
model1.fit(calc_rew.reshape(-1,1),exp)
beta1 = model1.intercept_
alpha1 = model1.coef_

# %%
####################################################################################

# %%
rew_sas = bme.Reweight()
rew_sas.load('exp_sas.txt','calc_saxs.txt')
t = 40
chi2_before_sas, chi2_after_sas, srel_sas = rew_sas.optimize(theta=t)
weights_sas = rew_sas.get_weights()
# Out:
# # SAS scaling factor 1.0081e+00
# # SAS offset -7.0769e-03
# # Warning: expt average         4.927702e+00=-4.8209e-03 is smaller than minimum value in simulation -3.3317e-03
# # theta: 40
# /home/francesco/KU/codes/bme_sas.py:410: RuntimeWarning: invalid value encountered in true_divide
#   ww /= zz
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-9bd4fde1d00c> in <module>()
#       2 rew_sas.load('exp_sas.txt','calc_saxs.txt')
#       3 t = 40
# ----> 4 chi2_before_sas, chi2_after_sas, srel_sas = rew_sas.optimize(theta=t)
#       5 weights_sas = rew_sas.get_weights()
#
# /home/francesco/KU/codes/bme_sas.py in optimize(self, theta, method)
#     473                 result = optimize.minimize(func_maxent_gauss,lambdas,
#     474                                 options=opt,method=meth, jac=True,
# --> 475 			        hess=hess_maxent_gauss)
# ...

# %%
rew_sas = bme.Reweight()
rew_sas.load('exp_sas.txt','calc_saxs.txt')
t = 1000
chi2_before_sas, chi2_after_sas, srel_sas = rew_sas.optimize(theta=t)
weights_sas = rew_sas.get_weights()
# Out:
# # SAS scaling factor 1.0081e+00
# # SAS offset -7.0769e-03
# # Warning: expt average         4.927702e+00=-4.8209e-03 is smaller than minimum value in simulation -3.3317e-03
# # theta: 1000

# %%
print(int(t), chi2_before_sas, chi2_after_sas, np.exp(srel_sas))
# Out:
# 40 5.380547036116558 3.1558924566873414 0.8489793629208273
